# %%
import numpy as np
import pandas as pd
students = np.random.randint(50,101,size=(50,5))
stu = pd.DataFrame(students,
             columns=['國文','英文','數學','地理','歷史'],
             index=[f'第{i}號' for i in range(1,51)]
             )
stu
# Out:
#        國文  英文   數學   地理   歷史
# 第1號    74  77   53   70   97
# 第2號    68  68   54   64   54
# 第3號    85  59   50   83   61
# 第4號    77  72   85   71   65
# 第5號    75  96   84   77   98
# 第6號    87  61   74   68   83
# 第7號    81  82   68   67   95
# 第8號    78  77   85   75   85
# 第9號    69  86   57   90   50
# 第10號   68  64   89   84   59
# 第11號   52  93   75   65   66
# 第12號   88  56   55   51   76
# 第13號   81  99   84   71   81
# 第14號  100  62   75   57   86
# 第15號   57  81   84   91   80
# 第16號   83  71   61   82   83
# 第17號   68  79   88   72   76
# 第18號   58  53   91   53   71
# 第19號   99  89   61   66   80
# 第20號   71  70   87   99   95
# 第21號   80  94   92   54   70
# 第22號   82  73   62   91   56
# 第23號   89  87   86   65   92
# 第24號   70  80   89   91   71
# 第25號   72  66   91   92   58
# 第26號   59  96   62   72   70
# 第27號   79  93   90   86   71
# 第28號   57  84  100   79   67
# 第29號   74  71   94   95   56
# 第30號   61  58   55   69   87
# 第31號   53  81   73   51   77
# 第32號   84  77   60   90   78
# 第33號   78  99   54   52   66
# 第34號   93  70  100  100   85
# 第35號   86  78   69   76  100
# 第36號   90  97   75   75   86
# 第37號   89  55   86   71   51
# 第38號   78  82   82  100   76
# 第39號   78  87   74   74   54
# 第40號   53  61   75   59   97
# 第41號   59  75   58   56   96
# 第42號   52  79   67   97   68
# 第43號   63  81   51   66   85
# 第44號   98  84   64   65   86
# 第45號  100  76   74   82   68
# 第46號   50  86   68   80   74
# 第47號  100  94   65   83   81
# 第48號   86  98   66   94   50
# 第49號   62  99   99   50   84
# 第50號   93  82   69   70   84

# %%
#陣列運算,使用數學運算子
stu['國文'] + stu['數學']

# %%
#陣列運算,使用比較運算子
stu['國文'] <= 60

# %%
#Series執行統計的方法
stu['國文'].sum()

# %%
#使用numpy統計方法
import numpy as np
np.sum(stu['國文'])

# %%
#DataFrame執行統計的方法
stu
stu['總分'] = stu.iloc[:,:5].sum(axis=1)
stu['平均'] = stu.iloc[:,:5].mean(axis=1)
stu

# %%
stu
stu['總分'] = np.sum(stu.iloc[:,:5],axis=1)
stu['平均'] = np.mean(stu.iloc[:,:5],axis=1)
stu

# %%
#使用seires的索引和index name
stu['總分'].iloc[0]
stu['總分']['第1號']

# %%
#Series sort
stu['總分'].sort_values()
sorted_s = stu['總分'].sort_values(ascending=False)

# %%
#使用sort_values(),取出前5分
sorted_s[:5]

# %%
#DataFrame sorted
sorted_df = stu.sort_values(by='總分',ascending=False)
sorted_df[:5]

# %%
sorted_df['排名'] = sorted_df['平均'].rank(ascending=False,method='first')
sorted_df

# %%
#使用subscript,搜尋值-國文不及格的
sorted_df[sorted_df['國文'] < 60]

# %%
#使用subscript,搜尋值-國文及格同時英文及格
sorted_df[(sorted_df['國文'] >= 60) & (sorted_df['數學'] >= 60)]
import numpy as np
sorted_df[(sorted_df['國文'] >= 60) & (sorted_df['數學'] >= 60)].shape[0]
