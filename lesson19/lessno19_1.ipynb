# %%
from PIL import Image
im = Image.open('8.jpg')
im.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=295x238>

# %%
import numpy as np
im = np.array(im)
im.shape
# Out:
# (238, 295, 3)

# %%
import numpy as np
im1 = np.array(Image.open('8.jpg'))
im_r = im[:,:,0]
im_r.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 im1 = np.array(Image.open('8.jpg'))
#       3 im_r = im[:,:,0]
# ----> 4 im_r.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'show'
